# %%
import pandas as pd

data = pd.read_csv('test.txt', delimiter='\t')
del data['id']
data.loc[:,'label'] = data.loc[:,'label']
data
# Out:
#                                turn1  \
# 0                                Hmm
# 1                      What you like
# 2                                Yes
# 3                 what did you guess
# 4                               We ?
# ...                              ...
# 5504                       Not youuu
# 5505                         Welcome
# 5506                             Yes
# 5507              For my information
# 5508  ok........... where you work ?
#
#                                                turn2  \
# 0                           What does your bio mean?
# 1                                 very little things
# 2                                            How so?
# 3                                          what what
# 4                                 of course we will!
# ...                                              ...
# 5504                          I also didn't not not.
# 5505                                 Why, thank you.
# 5506                     IF ONLY I COULD AFFORD THIS
# 5507  It's our responsibility to clarify everything.
# 5508                         I'm off this whole week
#
#                               turn3   label
# 0              I don’t have any bio  others
# 1                               Ok   others
# 2               I want to fuck babu  others
# 3                              fuck  others
# 4     What gender movies you like??  others
# ...                             ...     ...
# 5504                   How to calll  others
# 5505         I don't know, you tell  others
# 5506                    How are you  others
# 5507          What is mountain dew?  others
# 5508              ok..............   others
#
# [5509 rows x 4 columns]

# %%
sums = dict()
for label in data['label'].unique():
    sums[label] = sum(data['label']==label)
print(sums)
# Out:
# {'others': 4677, 'happy': 284, 'angry': 298, 'sad': 250}

# %%
data['text'] = data.turn1+' '+data.turn2+' '+data.turn3
data
# Out:
#                                turn1  \
# 0                                Hmm
# 1                      What you like
# 2                                Yes
# 3                 what did you guess
# 4                               We ?
# ...                              ...
# 5504                       Not youuu
# 5505                         Welcome
# 5506                             Yes
# 5507              For my information
# 5508  ok........... where you work ?
#
#                                                turn2  \
# 0                           What does your bio mean?
# 1                                 very little things
# 2                                            How so?
# 3                                          what what
# 4                                 of course we will!
# ...                                              ...
# 5504                          I also didn't not not.
# 5505                                 Why, thank you.
# 5506                     IF ONLY I COULD AFFORD THIS
# 5507  It's our responsibility to clarify everything.
# 5508                         I'm off this whole week
#
#                               turn3   label  \
# 0              I don’t have any bio  others
# 1                               Ok   others
# 2               I want to fuck babu  others
# 3                              fuck  others
# 4     What gender movies you like??  others
# ...                             ...     ...
# 5504                   How to calll  others
# 5505         I don't know, you tell  others
# 5506                    How are you  others
# 5507          What is mountain dew?  others
# 5508              ok..............   others
#
#                                                    text
# 0     Hmm What does your bio mean? I don’t have any bio
# 1                  What you like very little things Ok
# 2                       Yes How so? I want to fuck babu
# 3                     what did you guess what what fuck
# 4     We ? of course we will! What gender movies you...
# ...                                                 ...
# 5504      Not youuu I also didn't not not. How to calll
# 5505     Welcome Why, thank you. I don't know, you tell
# 5506        Yes IF ONLY I COULD AFFORD THIS How are you
# 5507  For my information It's our responsibility to ...
# 5508  ok........... where you work ? I'm off this wh...
#
# [5509 rows x 5 columns]

# %%
emotion_text = dict()
for label in data['label'].unique():
    emotion_text[label] = data[data['label']==label][['turn1', 'turn3']]

# %%
import emojis

import hunspell
from tokenizer import tokenizer

T = tokenizer.TweetTokenizer(regularize=False)
hobj = hunspell.HunSpell('/usr/share/hunspell/en_US.dic', '/usr/share/hunspell/en_US.aff')

exclamatives = dict.fromkeys(emotion_text.keys(),0)
interrogatives = dict.fromkeys(emotion_text.keys(),0)
upper_cases = dict.fromkeys(emotion_text.keys(),0)
lower_cases = dict.fromkeys(emotion_text.keys(),0)
emojis_s = dict.fromkeys(emotion_text.keys(),0)
unknown_words = dict.fromkeys(emotion_text.keys(),[])
unknown_words_len = dict.fromkeys(emotion_text.keys(),0)
avg_lengths = dict.fromkeys(emotion_text.keys(), 0)
for emotion, df in emotion_text.items():
    for sentence in df['turn1']+' '+df['turn3']:
        exclamatives[emotion] += sentence.count('?')
        interrogatives[emotion] += sentence.count('!')
        upper_cases[emotion] += sum(1 for l in sentence if l.isupper())
        lower_cases[emotion] += sum(1 for l in sentence if l.islower())
        emojis_s[emotion] += emojis.count(sentence)
        tokens = T.tokenize(sentence)
        for tok in tokens:
            if not hobj.spell(tok):
                unknown_words[emotion] += [tok]
                unknown_words_len[emotion] += 1   
            
        avg_lengths[emotion] += len(tokens)/sums[emotion]
        
for k,v in exclamatives.items():
    exclamatives[k] = exclamatives[k]
for k,v in interrogatives.items():
    interrogatives[k] = interrogatives[k]
for k,v in upper_cases.items():
    upper_cases[k] = upper_cases[k]
for k,v in upper_cases.items():
    lower_cases[k] = lower_cases[k]
for k,v in upper_cases.items():
    emojis_s[k] = emojis_s[k]
for k,v in unknown_words_len.items():
    unknown_words_len[k] = unknown_words_len[k]

    
print('exclamatives: \t\t', exclamatives)
print('interrogatives: \t', interrogatives)
print('upper_cases: \t\t', upper_cases)    
print('lower_cases: \t\t', lower_cases)    
print('emojis: \t\t', emojis_s)    
print('unknown_words_len: \t', unknown_words_len)    
print('avg_lengths: \t', avg_lengths)
# Out:
# exclamatives: 		 {'others': 1318, 'happy': 41, 'angry': 37, 'sad': 48}
# interrogatives: 	 {'others': 130, 'happy': 7, 'angry': 6, 'sad': 9}
# upper_cases: 		 {'others': 9470, 'happy': 519, 'angry': 645, 'sad': 495}
# lower_cases: 		 {'others': 120530, 'happy': 7048, 'angry': 8359, 'sad': 6860}
# emojis: 		 {'others': 361, 'happy': 203, 'angry': 30, 'sad': 167}
# unknown_words_len: 	 {'others': 4627, 'happy': 463, 'angry': 258, 'sad': 372}
# avg_lengths: 	 {'others': 35.543724609792434, 'happy': 34.904929577464806, 'angry': 38.67449664429531, 'sad': 38.84800000000002}

# %%
import emoji

emojis = list(emoji.UNICODE_EMOJI.keys())

for emo in emojis:
    print(emo)
# Out:
# en
# es
# pt
# it
